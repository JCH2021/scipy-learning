# %% [markdown]
# 这个库有好多地方都没有看懂，所以跳过了许多内容，后面学会了再更新

# %%
import numpy as np
from scipy.optimize import minimize

# %% [markdown]
# 计算下面公式的最小值
# $$f(x)=\sum_{i=1}^{N-1}{100(x_{i+1}-x_{i}^2)^2+(1-x_{i})^2}$$

# %%
def rosen(x):
    return sum(100.0*(x[1:]-x[:-1]**2.0)**2.0 + (1-x[:-1])**2.0)
x0 = np.array([1.3, 0.7, 0.8, 1.9, 1.2])
res = minimize(
    rosen, x0, method='powell',options={'xatol': 1e-8, 'disp': True}
)
#参数一是要最小化的函数，参数二是初步猜测
#参数三是解算器的类型，还有很多
#参数四是解算器选项词典，具体什么意思我还没懂
res
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 18
#          Function evaluations: 1084
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18488\1898244769.py:4: OptimizeWarning: Unknown solver options: xatol
#   res = minimize(
#    direc: array([[-5.04050381e-07, -2.91450372e-06, -3.73102198e-06,
#         -6.68348509e-06, -1.30888161e-05],
#        [-2.99937619e-03, -5.44579148e-03, -1.15336808e-02,
#         -2.32125403e-02, -4.51404333e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00],
#        [-6.53046464e-03, -4.12908316e-03, -1.29127384e-03,
#          5.08867880e-05,  1.21533142e-04],
#        [-1.42440408e-08, -2.89907128e-08, -5.68480023e-08,
#         -1.16937235e-07, -2.75813141e-07]])
#      fun: 1.6967633615782998e-22
#  message: 'Optimization terminated successfully.'
#     nfev: 1084
#      nit: 18
#   status: 0
#  success: True
#        x: array([1., 1., 1., 1., 1.])
