# %% [markdown]
# 虽然说的是傅里叶变换，但是我觉得和级数还是很相似的
#
# 我们先看一下官网的例子
# $$y[0]=\sum_{n=0}^{N-1}{x[n]}$$

# %%
import numpy as np
from scipy.fft import fft, ifft
x = np.array([1.0, 3.0, 1.0, 4])
y = fft(x)
y
#我只看出第一个值是数据之和，
#复数是因为傅里叶变换的定义采用了复数形式
# Out:
# array([ 9.-0.j,  0.+1.j, -5.-0.j,  0.-1.j])
